# %%
import os
import cv2
import torch
import open_clip
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
from ultralytics import YOLO
from collections import Counter
import time
import csv
import pandas as pd
import shutil

# Setup device for computations (CUDA if available, otherwise CPU)
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")

# Load OpenCLIP model and its preprocessor
# 'ViT-B-16' is the model architecture, 'laion400m_e32' is the pretrained weights
model, _, preprocess = open_clip.create_model_and_transforms(
    'ViT-B-16-quickgelu', pretrained='openai', device=device)

# load the fine-tuned model
# Ensure the correct path to your fine-tuned model weights
# model.load_state_dict(torch.load("finetuned_identity_only_best_ViT-B-16_openai.pt")); model.to(device=device).eval()

# Get the tokenizer specific to the loaded model
tokenizer = open_clip.get_tokenizer('ViT-B-16')

# Text prompts for identity - EXPANDED LIST
face_prompts = [
    "A face of Soekarno, a male First President (1945-1967) from Indonesia.",
    "A face of Suharto, a male Second President (1967-1998) from Indonesia.",
    "A face of Baharuddin Jusuf Habibie, a male Third President (1998-1999) from Indonesia.",
    "A face of Abdurrahman Wahid, a male Fourth President (1999-2001) from Indonesia.",
    "A face of Megawati Sukarnoputri, a female Fifth President (2001-2004) from Indonesia.",
    "A face of Susilo Bambang Yudhoyono, a male Sixth President (2004-2014) from Indonesia.",
    "A face of Joko Widodo, a male Seventh President (2014-2024) from Indonesia.",
    "A face of Prabowo Subianto, a male Eight President (2024-Present) from Indonesia.",
    "A face of Anies Rasyid Baswedan, a male Governor of Jakarta (2017-2022) and Presidential Candidate Election (2024) from Indonesia.",
    "A face of Ganjar Pranowo, a male Governor of Central Java (2013-2023) and Presidential Candidate Election (2024) from Indonesia.",
    "A face of Gibran Rakabuming Raka, a male Vice President (2024-2029) from Indonesia.",
    "A face of Maruf Amin, a male Vice President (2019-2024) from Indonesia.",
    "A face of Airlangga Hartarto, a male Coordinating Minister of Economic Affairs (2024-2029) from Indonesia.",
    "A face of Sri Mulyani Indrawati, a female Minister of Finance (2024-2029) from Indonesia.",
    "A face of Erick Thohir, a male Minister of State Owned Entreprises (2024-2029) from Indonesia.",
    "A face of Agus Harimurti Yudhoyono, a male Coordinating Minister of Agrarian Affairs and Spatial Planning (2024-2029) and Chairman of Democratic Party from Indonesia.",
    "A face of Muhaimin Iskandar, a male Coordinating Minister of Social Empowrement (2024-2029) and Chairman of National Awakening Party from Indonesia.",
    "A face of Mahfud MD, a male Coordinating Minister of Political, Legal, and Security Affairs (2019-2024) from Indonesia.",
    "A face of Boediono, a male Vice President (2009-2014) from Indonesia.",
    "A face of Jusuf Kalla, a male Vice President (2004-2009) and Vice President (2014-2019) from Indonesia.",
    f"A face of Unknown Person, who is not a politician."
]

# Extract simplified labels from face prompts (e.g., "Soekarno" from "A face of Soekarno, ...")
labels = [p.replace("A face of ", "").split(",")[0] for p in face_prompts]
label_list = ["Soekarno", "Suharto", "Baharuddin Jusuf Habibie", "Abdurrahman Wahid", "Megawati Sukarnoputri", "Susilo Bambang Yudhoyono", "Joko Widodo",
               "Prabowo Subianto", "Anies Rasyid Baswedan", "Ganjar Pranowo", "Gibran Rakabuming Raka", "Maruf Amin", "Airlangga Hartarto",
               "Sri Mulyani Indrawati", "Erick Thohir", "Agus Harimurti Yudhoyono", "Muhaimin Iskandar", "Mahfud MD", "Boediono", "Jusuf Kalla", "Unknown Person"]
# Create a mapping from extracted labels to their consistent keys
label_map = dict(zip(labels, label_list))

# --- REFINED: Folder Structure and Reverse Mapping ---
coalitions = {
    "KPP": [{"Independent": ["Anies Rasyid Baswedan"]},
            {"PKB": ["Muhaimin Iskandar", "Abdurrahman Wahid"]}],
    "KIM": [{"Independent": ["Erick Thohir"]},
            {"PDIP": ["Gibran Rakabuming Raka"]},
            {"Gerindra": ["Prabowo Subianto"]},
            {"Demokrat": ["Agus Harimurti Yudhoyono", "Susilo Bambang Yudhoyono"]},
            {"Golkar": ["Airlangga Hartarto", "Baharuddin Jusuf Habibie",  "Jusuf Kalla", "Suharto"]}],
    "KSP3GP": [{"Independent": ["Mahfud MD"]},
               {"PDIP": ["Ganjar Pranowo", "Megawati Sukarnoputri", "Joko Widodo", "Soekarno"]}],
    "Others": [{"Independent": ["Sri Mulyani Indrawati", "Boediono", "Maruf Amin"]}]
}

# Create a reverse lookup map from person to their coalition and party
person_to_party_map = {}
for coalition, parties in coalitions.items():
    for party_dict in parties:
        for party, members in party_dict.items():
            for member in members:
                # Use the consistent name from label_map for lookup
                person_key = label_map.get(member, member)
                person_to_party_map[person_key] = (coalition, party)


# Tokenize prompts
text_tokens = tokenizer(face_prompts).to(device)
with torch.no_grad():
    text_features = model.encode_text(text_tokens)
    text_features = text_features / text_features.norm(dim=-1, keepdim=True)

# Load YOLOv8 face detector
face_model = YOLO("yolov8l-face-lindevs.pt")
face_model.to(device)

# Final summary list
final_summary = []

# Helper function
def classify_with_clip(image_pil):
    try:
        image_pil = image_pil.convert("RGB")
        image_input = preprocess(image_pil).unsqueeze(0).to(device)
        with torch.no_grad():
            image_features = model.encode_image(image_input)
            image_features = image_features / image_features.norm(dim=-1, keepdim=True)
            similarity = (100.0 * image_features @ text_features.T).softmax(dim=-1)[0].cpu().numpy()
    except Exception as e:
        print(f"[ERROR] classify_with_clip failed: {e}")
        return "Unknown Person", 0.0

    identity_sim = similarity[:len(labels)]
    identity_idx = np.argmax(identity_sim)
    confidence = identity_sim[identity_idx]

    predicted_identity = labels[identity_idx] if confidence > 0.7 else "Unknown Person"
    return predicted_identity, confidence

# Define parent folders
parent_input_dir = "C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/third_discussion/extracted_frames"
parent_output_dir = "C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline"

# --- REFINED: Pre-create all destination directories ---
print("Pre-creating output directories...")
for coalition, parties in coalitions.items():
    for party_dict in parties:
        for party in party_dict.keys():
            os.makedirs(os.path.join(parent_output_dir, coalition, party), exist_ok=True)
# Create a folder for uncategorized videos
os.makedirs(os.path.join(parent_output_dir, "Uncategorized"), exist_ok=True)


# --- MODIFIED: Counters for periodic saving ---
processed_video_count = 0
summary_file_counter = 0
video_folders = os.listdir(parent_input_dir)[:100]
total_videos = len(video_folders)

# Process each video folder
for video_folder_name in video_folders:
    input_folder = os.path.join(parent_input_dir, video_folder_name)
    if not os.path.isdir(input_folder):
        continue

    # Create the initial result folder at the top level
    result_folder = os.path.join(parent_output_dir, video_folder_name)
    os.makedirs(result_folder, exist_ok=True)

    print(f"\n🚀 Processing video folder: {video_folder_name} ({processed_video_count + 1}/{total_videos})")

    identity_counter = Counter()
    # --- ADDED: Counter for frames with at least one known person ---
    frames_with_known_person_count = 0

    csv_path = os.path.join(result_folder, "inference_log.csv")
    csv_file = open(csv_path, mode='w', newline='', encoding='utf-8')
    csv_writer = csv.writer(csv_file)
    csv_writer.writerow(["frame_name", "face_identity", "confidence", "inference_time_sec"])

    start_time = time.time()

    image_files = sorted([f for f in os.listdir(input_folder) if f.lower().endswith(('.jpg', '.png'))])
    original_video_length_sec = len(image_files)

    for filename in image_files:
        image_path = os.path.join(input_folder, filename)
        bgr_img = cv2.imread(image_path)
        if bgr_img is None:
            print(f"Warning: Could not read image {image_path}, skipping.")
            continue
        rgb_img = cv2.cvtColor(bgr_img, cv2.COLOR_BGR2RGB)
        draw_img = rgb_img.copy()

        results = face_model.predict(image_path, conf=0.7, verbose=False)
        boxes = results[0].boxes.xyxy.cpu().numpy().astype(int)

        if len(boxes) == 0:
            continue

        identities_in_this_frame = set()
        frame_results_for_plotting = []

        for i, (x1, y1, x2, y2) in enumerate(boxes):
            face = rgb_img[y1:y2, x1:x2]
            face_pil = Image.fromarray(face).convert("RGB")

            face_start = time.time()
            predicted, confidence = classify_with_clip(face_pil)
            face_end = time.time()
            face_inference_time = face_end - face_start

            identities_in_this_frame.add(predicted)

            csv_writer.writerow([filename.split("_")[-1], predicted, f"{confidence:.4f}", f"{face_inference_time:.4f}"])

            cv2.rectangle(draw_img, (x1, y1), (x2, y2), (0, 255, 0), 3)

            frame_results_for_plotting.append({
                "face_img": face,
                "predicted": predicted,
                "confidence": confidence
            })

        if len(boxes) < 10:
            fig, axs = plt.subplots(1, len(boxes) + 1, figsize=(5 * (len(boxes) + 1), 5))

            axs[0].imshow(draw_img)
            axs[0].set_title("Original (bbox)")
            axs[0].axis("off")

            for i, result_data in enumerate(frame_results_for_plotting):
                axs[i + 1].imshow(result_data["face_img"])
                axs[i + 1].set_title(f"{result_data['predicted']}\n({result_data['confidence']:.2f})", fontsize=10)
                axs[i + 1].axis("off")

            plt.tight_layout()
            save_vis_path = os.path.join(result_folder, filename.split("_")[-1])
            plt.savefig(save_vis_path, dpi=100)
            plt.close('all')

        for person in identities_in_this_frame:
            identity_counter[person] += 1

        # --- REFINED: Increment frame counter if a known person was found ---
        if any(p != "Unknown Person" for p in identities_in_this_frame):
            frames_with_known_person_count += 1


    end_time = time.time()
    total_time_sec = end_time - start_time
    csv_file.close()

    main_character = "None"
    dominance_percentage = 0.0
    known_identity_counter = identity_counter.copy()
    if "Unknown Person" in known_identity_counter:
        del known_identity_counter["Unknown Person"]

    if known_identity_counter:
        most_common_person, count = known_identity_counter.most_common(1)[0]
        # --- FIXED: Use the correct total number of frames with known people ---
        dominance_percentage = (count / frames_with_known_person_count) * 100 if frames_with_known_person_count > 0 else 0

        if dominance_percentage > 30:
            main_character = most_common_person
            print(f"Dominant character found: {main_character} ({dominance_percentage:.1f}% of frames with known faces)")
        else:
            print(f"No dominant character. Top known character: {most_common_person} ({dominance_percentage:.1f}%) did not meet >30% threshold.")
    else:
        print("No known faces detected to determine dominance.")


    summary_path = os.path.join(result_folder, "summary.txt")
    with open(summary_path, "w", encoding="utf-8") as f:
        f.write("Face Appearance Summary (Most Frequent Identity in Video Sequence)\n")
        f.write("=" * 65 + "\n\n")

        if identity_counter:
            sorted_identities = identity_counter.most_common()
            total_frames_with_faces = sum(identity_counter.values())
            for name, count in sorted_identities:
                percentage = (count / total_frames_with_faces) * 100 if total_frames_with_faces > 0 else 0
                f.write(f"{name:<30} : appeared in {count:>3} frames ({percentage:5.1f}% of frames with faces)\n")

            f.write("\n" + "-" * 65 + "\n")
            if main_character != "None":
                f.write(f"🟩 Total Frames with Known Faces: {frames_with_known_person_count}\n")
                f.write(f"🟩 Dominant Character (>30% of frames with known faces): {main_character} ({dominance_percentage:.1f}% of frames with known faces)\n")
            else:
                f.write("❗ No single known character appeared in >30% of frames with face detections.\n")
        else:
            f.write("❗ No faces detected in the video sequence.\n")
        f.write("\nTotal Inference Time: {:.2f} minutes\n".format(total_time_sec / 60))

    summary_row = {"video_folder": video_folder_name}
    summary_row["main_character"] = main_character
    summary_row.update({k: 0 for k in label_list})
    for name, count in identity_counter.items():
        k = label_map.get(name, "Unknown Person")
        summary_row[k] = count
    summary_row["original_video_length_sec"] = original_video_length_sec
    summary_row["inference_time_sec"] = f"{total_time_sec:.2f}"
    final_summary.append(summary_row)

    print(f"\n✅ Done with: {video_folder_name}")

    if main_character != "None" and main_character in person_to_party_map:
        coalition, party = person_to_party_map[main_character]
        person_specific_dir = os.path.join(parent_output_dir, coalition, party, main_character.replace(" ", "_"))
        os.makedirs(person_specific_dir, exist_ok=True)
        destination_path = os.path.join(person_specific_dir, video_folder_name)
        print(f"Moving results to: {destination_path}")
        try:
            shutil.move(result_folder, destination_path)
        except shutil.Error as e:
            print(f"Could not move folder {video_folder_name}. It may already exist in the destination. Error: {e}")
    else:
        destination_dir = os.path.join(parent_output_dir, "Uncategorized")
        destination_path = os.path.join(destination_dir, video_folder_name)
        print(f"Main character '{main_character}' not dominant or not in map. Moving results to: {destination_path}")
        try:
            shutil.move(result_folder, destination_path)
        except shutil.Error as e:
            print(f"Could not move folder {video_folder_name} to Uncategorized. Error: {e}")


    processed_video_count += 1
    if processed_video_count % 100 == 0 and processed_video_count > 0:
        summary_file_counter += 1
        summary_filename = f"final_summary_{summary_file_counter:02d}.csv"
        final_summary_csv = os.path.join(parent_output_dir, summary_filename)

        print(f"\n💾 Checkpoint: Saving summary for videos {processed_video_count-99}-{processed_video_count}...")
        df = pd.DataFrame(final_summary)
        df.to_csv(final_summary_csv, index=False, encoding="utf-8")
        print(f"📝 Intermediate summary saved to: {final_summary_csv}")

        final_summary = []


if final_summary:
    print("\n🏁 All videos processed. Performing final save of remaining summary...")
    summary_file_counter += 1
    summary_filename = f"final_summary_{summary_file_counter:02d}.csv"
    final_summary_csv = os.path.join(parent_output_dir, summary_filename)

    df = pd.DataFrame(final_summary)
    df.to_csv(final_summary_csv, index=False, encoding="utf-8")
    print(f"\n📝 Final summary saved to: {final_summary_csv}")
else:
    print("\n🏁 All videos processed. No remaining data to save in a final chunk.")
# Out:
# Using device: cuda
# Pre-creating output directories...
#
# 🚀 Processing video folder: video-02menang-20240122061552-7326802529356893446 (1/100)
# No known faces detected to determine dominance.
#
# ✅ Done with: video-02menang-20240122061552-7326802529356893446
# Main character 'None' not dominant or not in map. Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Uncategorized\video-02menang-20240122061552-7326802529356893446
#
# 🚀 Processing video folder: video-02menang-20240131125449-7330245100531993861 (2/100)
# Dominant character found: Anies Rasyid Baswedan (100.0% of frames with known faces)
#
# ✅ Done with: video-02menang-20240131125449-7330245100531993861
# Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\KPP\Independent\Anies_Rasyid_Baswedan\video-02menang-20240131125449-7330245100531993861
#
# 🚀 Processing video folder: video-2024prabow-20231006103222-7286791431040093446 (3/100)
# Dominant character found: Erick Thohir (40.0% of frames with known faces)
#
# ✅ Done with: video-2024prabow-20231006103222-7286791431040093446
# Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\KIM\Independent\Erick_Thohir\video-2024prabow-20231006103222-7286791431040093446
#
# 🚀 Processing video folder: video-2024prabow-20231015072229-7290082262270397701 (4/100)
# Dominant character found: Prabowo Subianto (100.0% of frames with known faces)
#
# ✅ Done with: video-2024prabow-20231015072229-7290082262270397701
# Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\KIM\Gerindra\Prabowo_Subianto\video-2024prabow-20231015072229-7290082262270397701
#
# 🚀 Processing video folder: video-2024prabow-20231024192448-7293608167542361349 (5/100)
# No known faces detected to determine dominance.
#
# ✅ Done with: video-2024prabow-20231024192448-7293608167542361349
# Main character 'None' not dominant or not in map. Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Uncategorized\video-2024prabow-20231024192448-7293608167542361349
#
# 🚀 Processing video folder: video-2024prabow-20231025060411-7293772938115878150 (6/100)
# No known faces detected to determine dominance.
#
# ✅ Done with: video-2024prabow-20231025060411-7293772938115878150
# Main character 'None' not dominant or not in map. Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Uncategorized\video-2024prabow-20231025060411-7293772938115878150
#
# 🚀 Processing video folder: video-2024prabow-20231105074816-7297881690377145606 (7/100)
# Dominant character found: Megawati Sukarnoputri (66.7% of frames with known faces)
#
# ✅ Done with: video-2024prabow-20231105074816-7297881690377145606
# Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\KSP3GP\PDIP\Megawati_Sukarnoputri\video-2024prabow-20231105074816-7297881690377145606
#
# 🚀 Processing video folder: video-2024prabow-20231105085440-7297898806169832709 (8/100)
# Dominant character found: Prabowo Subianto (100.0% of frames with known faces)
#
# ✅ Done with: video-2024prabow-20231105085440-7297898806169832709
# Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\KIM\Gerindra\Prabowo_Subianto\video-2024prabow-20231105085440-7297898806169832709
#
# 🚀 Processing video folder: video-2024prabow-20231112055704-7300450628797615365 (9/100)
# No known faces detected to determine dominance.
#
# ✅ Done with: video-2024prabow-20231112055704-7300450628797615365
# Main character 'None' not dominant or not in map. Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Uncategorized\video-2024prabow-20231112055704-7300450628797615365
#
# 🚀 Processing video folder: video-2024prabow-20240121135220-7326549070468762885 (10/100)
# Dominant character found: Prabowo Subianto (50.0% of frames with known faces)
#
# ✅ Done with: video-2024prabow-20240121135220-7326549070468762885
# Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\KIM\Gerindra\Prabowo_Subianto\video-2024prabow-20240121135220-7326549070468762885
#
# 🚀 Processing video folder: video-2045tv-20221107113447-7163236139665558810 (11/100)
# Dominant character found: Joko Widodo (71.4% of frames with known faces)
#
# ✅ Done with: video-2045tv-20221107113447-7163236139665558810
# Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\KSP3GP\PDIP\Joko_Widodo\video-2045tv-20221107113447-7163236139665558810
#
# 🚀 Processing video folder: video-2045tv-20221119110420-7167681321207205147 (12/100)
# No known faces detected to determine dominance.
#
# ✅ Done with: video-2045tv-20221119110420-7167681321207205147
# Main character 'None' not dominant or not in map. Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Uncategorized\video-2045tv-20221119110420-7167681321207205147
#
# 🚀 Processing video folder: video-2045tv-20230203051046-7195792672198544667 (13/100)
# Dominant character found: Joko Widodo (75.0% of frames with known faces)
#
# ✅ Done with: video-2045tv-20230203051046-7195792672198544667
# Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\KSP3GP\PDIP\Joko_Widodo\video-2045tv-20230203051046-7195792672198544667
#
# 🚀 Processing video folder: video-2045tv-20230208050949-7197647854918257947 (14/100)
# Dominant character found: Boediono (100.0% of frames with known faces)
#
# ✅ Done with: video-2045tv-20230208050949-7197647854918257947
# Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Others\Independent\Boediono\video-2045tv-20230208050949-7197647854918257947
#
# 🚀 Processing video folder: video-2045tv-20230309042042-7208396640330321178 (15/100)
# Dominant character found: Megawati Sukarnoputri (100.0% of frames with known faces)
#
# ✅ Done with: video-2045tv-20230309042042-7208396640330321178
# Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\KSP3GP\PDIP\Megawati_Sukarnoputri\video-2045tv-20230309042042-7208396640330321178
#
# 🚀 Processing video folder: video-2045tv-20230330072023-7216235729645522203 (16/100)
# No known faces detected to determine dominance.
#
# ✅ Done with: video-2045tv-20230330072023-7216235729645522203
# Main character 'None' not dominant or not in map. Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Uncategorized\video-2045tv-20230330072023-7216235729645522203
#
# 🚀 Processing video folder: video-2045tv-20230419133627-7223754379571023130 (17/100)
# Dominant character found: Muhaimin Iskandar (100.0% of frames with known faces)
#
# ✅ Done with: video-2045tv-20230419133627-7223754379571023130
# Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\KPP\PKB\Muhaimin_Iskandar\video-2045tv-20230419133627-7223754379571023130
#
# 🚀 Processing video folder: video-2045tv-20230420104033-7224080119407627546 (18/100)
# No known faces detected to determine dominance.
#
# ✅ Done with: video-2045tv-20230420104033-7224080119407627546
# Main character 'None' not dominant or not in map. Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Uncategorized\video-2045tv-20230420104033-7224080119407627546
#
# 🚀 Processing video folder: video-2045tv-20230421143641-7224512061592669466 (19/100)
# No known faces detected to determine dominance.
#
# ✅ Done with: video-2045tv-20230421143641-7224512061592669466
# Main character 'None' not dominant or not in map. Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Uncategorized\video-2045tv-20230421143641-7224512061592669466
#
# 🚀 Processing video folder: video-2045tv-20230622124202-7247489819985661190 (20/100)
# Dominant character found: Mahfud MD (100.0% of frames with known faces)
#
# ✅ Done with: video-2045tv-20230622124202-7247489819985661190
# Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\KSP3GP\Independent\Mahfud_MD\video-2045tv-20230622124202-7247489819985661190
#
# 🚀 Processing video folder: video-2045tv-20230801053125-7262222251381181701 (21/100)
# Dominant character found: Joko Widodo (100.0% of frames with known faces)
#
# ✅ Done with: video-2045tv-20230801053125-7262222251381181701
# Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\KSP3GP\PDIP\Joko_Widodo\video-2045tv-20230801053125-7262222251381181701
#
# 🚀 Processing video folder: video-2045tv-20230811061933-7265945512879066373 (22/100)
# Dominant character found: Megawati Sukarnoputri (100.0% of frames with known faces)
#
# ✅ Done with: video-2045tv-20230811061933-7265945512879066373
# Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\KSP3GP\PDIP\Megawati_Sukarnoputri\video-2045tv-20230811061933-7265945512879066373
#
# 🚀 Processing video folder: video-2045tv-20230815082201-7267461404179893509 (23/100)
# No known faces detected to determine dominance.
#
# ✅ Done with: video-2045tv-20230815082201-7267461404179893509
# Main character 'None' not dominant or not in map. Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Uncategorized\video-2045tv-20230815082201-7267461404179893509
#
# 🚀 Processing video folder: video-2045tv-20231123085911-7304579317059570952 (24/100)
# Dominant character found: Prabowo Subianto (100.0% of frames with known faces)
#
# ✅ Done with: video-2045tv-20231123085911-7304579317059570952
# Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\KIM\Gerindra\Prabowo_Subianto\video-2045tv-20231123085911-7304579317059570952
#
# 🚀 Processing video folder: video-2045tv-20231127084500-7306049291871587586 (25/100)
# No known faces detected to determine dominance.
#
# ✅ Done with: video-2045tv-20231127084500-7306049291871587586
# Main character 'None' not dominant or not in map. Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Uncategorized\video-2045tv-20231127084500-7306049291871587586
#
# 🚀 Processing video folder: video-2045tv-20231127112239-7306100649488403714 (26/100)
# No known faces detected to determine dominance.
#
# ✅ Done with: video-2045tv-20231127112239-7306100649488403714
# Main character 'None' not dominant or not in map. Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Uncategorized\video-2045tv-20231127112239-7306100649488403714
#
# 🚀 Processing video folder: video-2045tv-20231218062000-7313808207695154433 (27/100)
# Dominant character found: Prabowo Subianto (100.0% of frames with known faces)
#
# ✅ Done with: video-2045tv-20231218062000-7313808207695154433
# Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\KIM\Gerindra\Prabowo_Subianto\video-2045tv-20231218062000-7313808207695154433
#
# 🚀 Processing video folder: video-2045tv-20231222132812-7315410136498015506 (28/100)
# No known faces detected to determine dominance.
#
# ✅ Done with: video-2045tv-20231222132812-7315410136498015506
# Main character 'None' not dominant or not in map. Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Uncategorized\video-2045tv-20231222132812-7315410136498015506
#
# 🚀 Processing video folder: video-2045tv-20240121142544-7326557540857220354 (29/100)
# No known faces detected to determine dominance.
#
# ✅ Done with: video-2045tv-20240121142544-7326557540857220354
# Main character 'None' not dominant or not in map. Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Uncategorized\video-2045tv-20240121142544-7326557540857220354
#
# 🚀 Processing video folder: video-2045tv-20240127055145-7328651707569671429 (30/100)
# Dominant character found: Megawati Sukarnoputri (100.0% of frames with known faces)
#
# ✅ Done with: video-2045tv-20240127055145-7328651707569671429
# Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\KSP3GP\PDIP\Megawati_Sukarnoputri\video-2045tv-20240127055145-7328651707569671429
#
# 🚀 Processing video folder: video-2045tv-20240201060000-7330208532861586696 (31/100)
# Dominant character found: Suharto (100.0% of frames with known faces)
#
# ✅ Done with: video-2045tv-20240201060000-7330208532861586696
# Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\KIM\Golkar\Suharto\video-2045tv-20240201060000-7330208532861586696
#
# 🚀 Processing video folder: video-23januari1-20231201071948-7307522577247800581 (32/100)
# No known faces detected to determine dominance.
#
# ✅ Done with: video-23januari1-20231201071948-7307522577247800581
# Main character 'None' not dominant or not in map. Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Uncategorized\video-23januari1-20231201071948-7307522577247800581
#
# 🚀 Processing video folder: video-23januari1-20231212015710-7311521364131859717 (33/100)
# Dominant character found: Boediono (100.0% of frames with known faces)
#
# ✅ Done with: video-23januari1-20231212015710-7311521364131859717
# Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Others\Independent\Boediono\video-23januari1-20231212015710-7311521364131859717
#
# 🚀 Processing video folder: video-62bergerak-20231204104530-7308688841869741318 (34/100)
# Dominant character found: Joko Widodo (66.7% of frames with known faces)
#
# ✅ Done with: video-62bergerak-20231204104530-7308688841869741318
# Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\KSP3GP\PDIP\Joko_Widodo\video-62bergerak-20231204104530-7308688841869741318
#
# 🚀 Processing video folder: video-62bergerak-20231214094256-7312383567668055302 (35/100)
# Dominant character found: Prabowo Subianto (62.5% of frames with known faces)
#
# ✅ Done with: video-62bergerak-20231214094256-7312383567668055302
# Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\KIM\Gerindra\Prabowo_Subianto\video-62bergerak-20231214094256-7312383567668055302
#
# 🚀 Processing video folder: video-72yudi-20240121142122-7326556558907739398 (36/100)
# No known faces detected to determine dominance.
#
# ✅ Done with: video-72yudi-20240121142122-7326556558907739398
# Main character 'None' not dominant or not in map. Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Uncategorized\video-72yudi-20240121142122-7326556558907739398
#
# 🚀 Processing video folder: video-72yudi-20240125054541-7327907995810106630 (37/100)
# No known faces detected to determine dominance.
#
# ✅ Done with: video-72yudi-20240125054541-7327907995810106630
# Main character 'None' not dominant or not in map. Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Uncategorized\video-72yudi-20240125054541-7327907995810106630
#
# 🚀 Processing video folder: video-8aswedan-20231031025118-7295949741559450886 (38/100)
# No known faces detected to determine dominance.
#
# ✅ Done with: video-8aswedan-20231031025118-7295949741559450886
# Main character 'None' not dominant or not in map. Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Uncategorized\video-8aswedan-20231031025118-7295949741559450886
#
# 🚀 Processing video folder: video-8aswedan-20231112044919-7300433177460346118 (39/100)
# Dominant character found: Agus Harimurti Yudhoyono (100.0% of frames with known faces)
#
# ✅ Done with: video-8aswedan-20231112044919-7300433177460346118
# Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\KIM\Demokrat\Agus_Harimurti_Yudhoyono\video-8aswedan-20231112044919-7300433177460346118
#
# 🚀 Processing video folder: video-8aswedan-20231113040340-7300792491735928069 (40/100)
# Dominant character found: Anies Rasyid Baswedan (100.0% of frames with known faces)
#
# ✅ Done with: video-8aswedan-20231113040340-7300792491735928069
# Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\KPP\Independent\Anies_Rasyid_Baswedan\video-8aswedan-20231113040340-7300792491735928069
#
# 🚀 Processing video folder: video-8aswedan-20231114052426-7301184394289597702 (41/100)
# No known faces detected to determine dominance.
#
# ✅ Done with: video-8aswedan-20231114052426-7301184394289597702
# Main character 'None' not dominant or not in map. Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Uncategorized\video-8aswedan-20231114052426-7301184394289597702
#
# 🚀 Processing video folder: video-8aswedan-20231114134642-7301313833086373126 (42/100)
# No known faces detected to determine dominance.
#
# ✅ Done with: video-8aswedan-20231114134642-7301313833086373126
# Main character 'None' not dominant or not in map. Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Uncategorized\video-8aswedan-20231114134642-7301313833086373126
#
# 🚀 Processing video folder: video-8aswedan-20231205130913-7309096965667704070 (43/100)
# No known faces detected to determine dominance.
#
# ✅ Done with: video-8aswedan-20231205130913-7309096965667704070
# Main character 'None' not dominant or not in map. Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Uncategorized\video-8aswedan-20231205130913-7309096965667704070
#
# 🚀 Processing video folder: video-929alfatih-20231204104129-7308687804513438982 (44/100)
# Dominant character found: Joko Widodo (100.0% of frames with known faces)
#
# ✅ Done with: video-929alfatih-20231204104129-7308687804513438982
# Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\KSP3GP\PDIP\Joko_Widodo\video-929alfatih-20231204104129-7308687804513438982
#
# 🚀 Processing video folder: video-99lkscahya-20231115033756-7301528035356904709 (45/100)
# Dominant character found: Megawati Sukarnoputri (100.0% of frames with known faces)
#
# ✅ Done with: video-99lkscahya-20231115033756-7301528035356904709
# Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\KSP3GP\PDIP\Megawati_Sukarnoputri\video-99lkscahya-20231115033756-7301528035356904709
#
# 🚀 Processing video folder: video-99lkscahya-20231121050457-7303776973636046085 (46/100)
# No known faces detected to determine dominance.
#
# ✅ Done with: video-99lkscahya-20231121050457-7303776973636046085
# Main character 'None' not dominant or not in map. Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Uncategorized\video-99lkscahya-20231121050457-7303776973636046085
#
# 🚀 Processing video folder: video-aaferdii-20240128113432-7329111161545215237 (47/100)
# No known faces detected to determine dominance.
#
# ✅ Done with: video-aaferdii-20240128113432-7329111161545215237
# Main character 'None' not dominant or not in map. Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Uncategorized\video-aaferdii-20240128113432-7329111161545215237
#
# 🚀 Processing video folder: video-aaferdii-20240129120338-7329489744239299845 (48/100)
# No known faces detected to determine dominance.
#
# ✅ Done with: video-aaferdii-20240129120338-7329489744239299845
# Main character 'None' not dominant or not in map. Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Uncategorized\video-aaferdii-20240129120338-7329489744239299845
#
# 🚀 Processing video folder: video-aaifan-20240115020556-7324140520521927941 (49/100)
# No known faces detected to determine dominance.
#
# ✅ Done with: video-aaifan-20240115020556-7324140520521927941
# Main character 'None' not dominant or not in map. Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Uncategorized\video-aaifan-20240115020556-7324140520521927941
#
# 🚀 Processing video folder: video-aaifan-20240123160712-7327326001829268742 (50/100)
# No known faces detected to determine dominance.
#
# ✅ Done with: video-aaifan-20240123160712-7327326001829268742
# Main character 'None' not dominant or not in map. Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Uncategorized\video-aaifan-20240123160712-7327326001829268742
#
# 🚀 Processing video folder: video-aananwar3-20240109084335-7322016486296423686 (51/100)
# Dominant character found: Joko Widodo (52.2% of frames with known faces)
#
# ✅ Done with: video-aananwar3-20240109084335-7322016486296423686
# Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\KSP3GP\PDIP\Joko_Widodo\video-aananwar3-20240109084335-7322016486296423686
#
# 🚀 Processing video folder: video-aananwar3-20240120062715-7326063283687951621 (52/100)
# No known faces detected to determine dominance.
#
# ✅ Done with: video-aananwar3-20240120062715-7326063283687951621
# Main character 'None' not dominant or not in map. Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Uncategorized\video-aananwar3-20240120062715-7326063283687951621
#
# 🚀 Processing video folder: video-abimanyuny-20240201075707-7330539468677565702 (53/100)
# Dominant character found: Joko Widodo (50.0% of frames with known faces)
#
# ✅ Done with: video-abimanyuny-20240201075707-7330539468677565702
# Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\KSP3GP\PDIP\Joko_Widodo\video-abimanyuny-20240201075707-7330539468677565702
#
# 🚀 Processing video folder: video-abimanyuny-20240221102828-7338000172221287685 (54/100)
# Dominant character found: Megawati Sukarnoputri (100.0% of frames with known faces)
#
# ✅ Done with: video-abimanyuny-20240221102828-7338000172221287685
# Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\KSP3GP\PDIP\Megawati_Sukarnoputri\video-abimanyuny-20240221102828-7338000172221287685
#
# 🚀 Processing video folder: video-abudjenar-20231018174732-7291356572444364038 (55/100)
# No known faces detected to determine dominance.
#
# ✅ Done with: video-abudjenar-20231018174732-7291356572444364038
# Main character 'None' not dominant or not in map. Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Uncategorized\video-abudjenar-20231018174732-7291356572444364038
#
# 🚀 Processing video folder: video-abudjenar-20231025064338-7293783095612951813 (56/100)
# Dominant character found: Megawati Sukarnoputri (100.0% of frames with known faces)
#
# ✅ Done with: video-abudjenar-20231025064338-7293783095612951813
# Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\KSP3GP\PDIP\Megawati_Sukarnoputri\video-abudjenar-20231025064338-7293783095612951813
#
# 🚀 Processing video folder: video-abudjenar-20231025175233-7293955482484526342 (57/100)
# Dominant character found: Joko Widodo (57.1% of frames with known faces)
#
# ✅ Done with: video-abudjenar-20231025175233-7293955482484526342
# Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\KSP3GP\PDIP\Joko_Widodo\video-abudjenar-20231025175233-7293955482484526342
#
# 🚀 Processing video folder: video-abudjenar-20231028094712-7294943664701263110 (58/100)
# Dominant character found: Megawati Sukarnoputri (100.0% of frames with known faces)
#
# ✅ Done with: video-abudjenar-20231028094712-7294943664701263110
# Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\KSP3GP\PDIP\Megawati_Sukarnoputri\video-abudjenar-20231028094712-7294943664701263110
#
# 🚀 Processing video folder: video-abudjenar-20231115130530-7301674299239304453 (59/100)
# No known faces detected to determine dominance.
#
# ✅ Done with: video-abudjenar-20231115130530-7301674299239304453
# Main character 'None' not dominant or not in map. Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Uncategorized\video-abudjenar-20231115130530-7301674299239304453
#
# 🚀 Processing video folder: video-abudjenar-20231130105829-7307207842052771077 (60/100)
# No known faces detected to determine dominance.
#
# ✅ Done with: video-abudjenar-20231130105829-7307207842052771077
# Main character 'None' not dominant or not in map. Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Uncategorized\video-abudjenar-20231130105829-7307207842052771077
#
# 🚀 Processing video folder: video-abudjenar-20231219031416-7314138832516041989 (61/100)
# No known faces detected to determine dominance.
#
# ✅ Done with: video-abudjenar-20231219031416-7314138832516041989
# Main character 'None' not dominant or not in map. Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Uncategorized\video-abudjenar-20231219031416-7314138832516041989
#
# 🚀 Processing video folder: video-abudjenar-20231227014405-7317084246311570693 (62/100)
# Dominant character found: Boediono (100.0% of frames with known faces)
#
# ✅ Done with: video-abudjenar-20231227014405-7317084246311570693
# Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Others\Independent\Boediono\video-abudjenar-20231227014405-7317084246311570693
#
# 🚀 Processing video folder: video-abu_umarst-20240213231856-7335230044299676934 (63/100)
# Dominant character found: Muhaimin Iskandar (100.0% of frames with known faces)
#
# ✅ Done with: video-abu_umarst-20240213231856-7335230044299676934
# Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\KPP\PKB\Muhaimin_Iskandar\video-abu_umarst-20240213231856-7335230044299676934
#
# 🚀 Processing video folder: video-abu_umarst-20240223141142-7338799880514686213 (64/100)
# Dominant character found: Anies Rasyid Baswedan (100.0% of frames with known faces)
#
# ✅ Done with: video-abu_umarst-20240223141142-7338799880514686213
# Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\KPP\Independent\Anies_Rasyid_Baswedan\video-abu_umarst-20240223141142-7338799880514686213
#
# 🚀 Processing video folder: video-actualnews-20240105164649-7320656669753740550 (65/100)
# Dominant character found: Megawati Sukarnoputri (66.7% of frames with known faces)
#
# ✅ Done with: video-actualnews-20240105164649-7320656669753740550
# Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\KSP3GP\PDIP\Megawati_Sukarnoputri\video-actualnews-20240105164649-7320656669753740550
#
# 🚀 Processing video folder: video-actualnews-20240105192343-7320697109257145606 (66/100)
# Dominant character found: Prabowo Subianto (66.7% of frames with known faces)
#
# ✅ Done with: video-actualnews-20240105192343-7320697109257145606
# Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\KIM\Gerindra\Prabowo_Subianto\video-actualnews-20240105192343-7320697109257145606
#
# 🚀 Processing video folder: video-ade98751-20231117111851-7302388989355461894 (67/100)
# No known faces detected to determine dominance.
#
# ✅ Done with: video-ade98751-20231117111851-7302388989355461894
# Main character 'None' not dominant or not in map. Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Uncategorized\video-ade98751-20231117111851-7302388989355461894
#
# 🚀 Processing video folder: video-ade98751-20231222163852-7315459438872153349 (68/100)
# Dominant character found: Megawati Sukarnoputri (66.7% of frames with known faces)
#
# ✅ Done with: video-ade98751-20231222163852-7315459438872153349
# Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\KSP3GP\PDIP\Megawati_Sukarnoputri\video-ade98751-20231222163852-7315459438872153349
#
# 🚀 Processing video folder: video-ade98751-20240219053955-7337183648405441797 (69/100)
# Dominant character found: Suharto (100.0% of frames with known faces)
#
# ✅ Done with: video-ade98751-20240219053955-7337183648405441797
# Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\KIM\Golkar\Suharto\video-ade98751-20240219053955-7337183648405441797
#
# 🚀 Processing video folder: video-adiannapit-20231120153020-7303567055217757445 (70/100)
# No known faces detected to determine dominance.
#
# ✅ Done with: video-adiannapit-20231120153020-7303567055217757445
# Main character 'None' not dominant or not in map. Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Uncategorized\video-adiannapit-20231120153020-7303567055217757445
#
# 🚀 Processing video folder: video-adiannapit-20231128030153-7306342848679480582 (71/100)
# Dominant character found: Prabowo Subianto (100.0% of frames with known faces)
#
# ✅ Done with: video-adiannapit-20231128030153-7306342848679480582
# Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\KIM\Gerindra\Prabowo_Subianto\video-adiannapit-20231128030153-7306342848679480582
#
# 🚀 Processing video folder: video-adiannapit-20231210111945-7310924175483440389 (72/100)
# No known faces detected to determine dominance.
#
# ✅ Done with: video-adiannapit-20231210111945-7310924175483440389
# Main character 'None' not dominant or not in map. Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Uncategorized\video-adiannapit-20231210111945-7310924175483440389
#
# 🚀 Processing video folder: video-adiannapit-20231215152514-7312842865997139206 (73/100)
# Dominant character found: Boediono (100.0% of frames with known faces)
#
# ✅ Done with: video-adiannapit-20231215152514-7312842865997139206
# Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Others\Independent\Boediono\video-adiannapit-20231215152514-7312842865997139206
#
# 🚀 Processing video folder: video-adie_ms-20231020113344-7292002439828393221 (74/100)
# Dominant character found: Muhaimin Iskandar (100.0% of frames with known faces)
#
# ✅ Done with: video-adie_ms-20231020113344-7292002439828393221
# Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\KPP\PKB\Muhaimin_Iskandar\video-adie_ms-20231020113344-7292002439828393221
#
# 🚀 Processing video folder: video-adie_ms-20231021232648-7292557271744204038 (75/100)
# No known faces detected to determine dominance.
#
# ✅ Done with: video-adie_ms-20231021232648-7292557271744204038
# Main character 'None' not dominant or not in map. Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Uncategorized\video-adie_ms-20231021232648-7292557271744204038
#
# 🚀 Processing video folder: video-adie_ms-20231022133241-7292775261634907397 (76/100)
# No known faces detected to determine dominance.
#
# ✅ Done with: video-adie_ms-20231022133241-7292775261634907397
# Main character 'None' not dominant or not in map. Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Uncategorized\video-adie_ms-20231022133241-7292775261634907397
#
# 🚀 Processing video folder: video-adie_ms-20231023082229-7293066408462667014 (77/100)
# No known faces detected to determine dominance.
#
# ✅ Done with: video-adie_ms-20231023082229-7293066408462667014
# Main character 'None' not dominant or not in map. Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Uncategorized\video-adie_ms-20231023082229-7293066408462667014
#
# 🚀 Processing video folder: video-adie_ms-20231114091403-7301243568088173829 (78/100)
# No known faces detected to determine dominance.
#
# ✅ Done with: video-adie_ms-20231114091403-7301243568088173829
# Main character 'None' not dominant or not in map. Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Uncategorized\video-adie_ms-20231114091403-7301243568088173829
#
# 🚀 Processing video folder: video-adinataby-20240106143728-7320994401713491201 (79/100)
# No known faces detected to determine dominance.
#
# ✅ Done with: video-adinataby-20240106143728-7320994401713491201
# Main character 'None' not dominant or not in map. Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Uncategorized\video-adinataby-20240106143728-7320994401713491201
#
# 🚀 Processing video folder: video-adinataby-20240116040541-7324542464822463750 (80/100)
# Dominant character found: Megawati Sukarnoputri (100.0% of frames with known faces)
#
# ✅ Done with: video-adinataby-20240116040541-7324542464822463750
# Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\KSP3GP\PDIP\Megawati_Sukarnoputri\video-adinataby-20240116040541-7324542464822463750
#
# 🚀 Processing video folder: video-adinataby-20240119135721-7325808202023488774 (81/100)
# No known faces detected to determine dominance.
#
# ✅ Done with: video-adinataby-20240119135721-7325808202023488774
# Main character 'None' not dominant or not in map. Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Uncategorized\video-adinataby-20240119135721-7325808202023488774
#
# 🚀 Processing video folder: video-adinataby-20240123124901-7327274916364045570 (82/100)
# Dominant character found: Prabowo Subianto (100.0% of frames with known faces)
#
# ✅ Done with: video-adinataby-20240123124901-7327274916364045570
# Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\KIM\Gerindra\Prabowo_Subianto\video-adinataby-20240123124901-7327274916364045570
#
# 🚀 Processing video folder: video-adinataby-20240129043203-7329373323513711874 (83/100)
# Dominant character found: Megawati Sukarnoputri (100.0% of frames with known faces)
#
# ✅ Done with: video-adinataby-20240129043203-7329373323513711874
# Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\KSP3GP\PDIP\Megawati_Sukarnoputri\video-adinataby-20240129043203-7329373323513711874
#
# 🚀 Processing video folder: video-adinataby-20240203155545-7331404958559915265 (84/100)
# Dominant character found: Megawati Sukarnoputri (66.7% of frames with known faces)
#
# ✅ Done with: video-adinataby-20240203155545-7331404958559915265
# Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\KSP3GP\PDIP\Megawati_Sukarnoputri\video-adinataby-20240203155545-7331404958559915265
#
# 🚀 Processing video folder: video-adisyahrez-20240110040508-7322315816551091462 (85/100)
# Dominant character found: Megawati Sukarnoputri (100.0% of frames with known faces)
#
# ✅ Done with: video-adisyahrez-20240110040508-7322315816551091462
# Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\KSP3GP\PDIP\Megawati_Sukarnoputri\video-adisyahrez-20240110040508-7322315816551091462
#
# 🚀 Processing video folder: video-adisyahrez-20240111044220-7322696486104403206 (86/100)
# No known faces detected to determine dominance.
#
# ✅ Done with: video-adisyahrez-20240111044220-7322696486104403206
# Main character 'None' not dominant or not in map. Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Uncategorized\video-adisyahrez-20240111044220-7322696486104403206
#
# 🚀 Processing video folder: video-adisyahrez-20240112035232-7323054745634000133 (87/100)
# No known faces detected to determine dominance.
#
# ✅ Done with: video-adisyahrez-20240112035232-7323054745634000133
# Main character 'None' not dominant or not in map. Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Uncategorized\video-adisyahrez-20240112035232-7323054745634000133
#
# 🚀 Processing video folder: video-adisyahrez-20240122045338-7326781334649703685 (88/100)
# No known faces detected to determine dominance.
#
# ✅ Done with: video-adisyahrez-20240122045338-7326781334649703685
# Main character 'None' not dominant or not in map. Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Uncategorized\video-adisyahrez-20240122045338-7326781334649703685
#
# 🚀 Processing video folder: video-adisyahrez-20240122071749-7326818493960031493 (89/100)
# No known faces detected to determine dominance.
#
# ✅ Done with: video-adisyahrez-20240122071749-7326818493960031493
# Main character 'None' not dominant or not in map. Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Uncategorized\video-adisyahrez-20240122071749-7326818493960031493
#
# 🚀 Processing video folder: video-adisyahrez-20240122101654-7326864640959319301 (90/100)
# No known faces detected to determine dominance.
#
# ✅ Done with: video-adisyahrez-20240122101654-7326864640959319301
# Main character 'None' not dominant or not in map. Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Uncategorized\video-adisyahrez-20240122101654-7326864640959319301
#
# 🚀 Processing video folder: video-adisyahrez-20240124103134-7327610595577040133 (91/100)
# No known faces detected to determine dominance.
#
# ✅ Done with: video-adisyahrez-20240124103134-7327610595577040133
# Main character 'None' not dominant or not in map. Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Uncategorized\video-adisyahrez-20240124103134-7327610595577040133
#
# 🚀 Processing video folder: video-adisyahrez-20240127053046-7328646329880562949 (92/100)
# Dominant character found: Prabowo Subianto (100.0% of frames with known faces)
#
# ✅ Done with: video-adisyahrez-20240127053046-7328646329880562949
# Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\KIM\Gerindra\Prabowo_Subianto\video-adisyahrez-20240127053046-7328646329880562949
#
# 🚀 Processing video folder: video-adisyahrez-20240214113555-7335419965832465669 (93/100)
# No known faces detected to determine dominance.
#
# ✅ Done with: video-adisyahrez-20240214113555-7335419965832465669
# Main character 'None' not dominant or not in map. Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Uncategorized\video-adisyahrez-20240214113555-7335419965832465669
#
# 🚀 Processing video folder: video-adrielviar-20240108110719-7321682439691160837 (94/100)
# Dominant character found: Boediono (94.7% of frames with known faces)
#
# ✅ Done with: video-adrielviar-20240108110719-7321682439691160837
# Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Others\Independent\Boediono\video-adrielviar-20240108110719-7321682439691160837
#
# 🚀 Processing video folder: video-adrielviar-20240109115628-7322066197153877254 (95/100)
# Dominant character found: Boediono (100.0% of frames with known faces)
#
# ✅ Done with: video-adrielviar-20240109115628-7322066197153877254
# Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Others\Independent\Boediono\video-adrielviar-20240109115628-7322066197153877254
#
# 🚀 Processing video folder: video-adrielviar-20240112105942-7323164825633230086 (96/100)
# Dominant character found: Boediono (100.0% of frames with known faces)
#
# ✅ Done with: video-adrielviar-20240112105942-7323164825633230086
# Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Others\Independent\Boediono\video-adrielviar-20240112105942-7323164825633230086
#
# 🚀 Processing video folder: video-adrielviar-20240115105511-7324276910723173637 (97/100)
# No known faces detected to determine dominance.
#
# ✅ Done with: video-adrielviar-20240115105511-7324276910723173637
# Main character 'None' not dominant or not in map. Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Uncategorized\video-adrielviar-20240115105511-7324276910723173637
#
# 🚀 Processing video folder: video-adrielviar-20240119111759-7325767126906686725 (98/100)
# No known faces detected to determine dominance.
#
# ✅ Done with: video-adrielviar-20240119111759-7325767126906686725
# Main character 'None' not dominant or not in map. Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Uncategorized\video-adrielviar-20240119111759-7325767126906686725
#
# 🚀 Processing video folder: video-adrielviar-20240120110252-7326134314243083525 (99/100)
# Dominant character found: Boediono (100.0% of frames with known faces)
#
# ✅ Done with: video-adrielviar-20240120110252-7326134314243083525
# Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Others\Independent\Boediono\video-adrielviar-20240120110252-7326134314243083525
#
# 🚀 Processing video folder: video-adrielviar-20240122044855-7326780113226386693 (100/100)
# No known faces detected to determine dominance.
#
# ✅ Done with: video-adrielviar-20240122044855-7326780113226386693
# Main character 'None' not dominant or not in map. Moving results to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\Uncategorized\video-adrielviar-20240122044855-7326780113226386693
#
# 💾 Checkpoint: Saving summary for videos 1-100...
# 📝 Intermediate summary saved to: C:/Users/yehte/Downloads/Ye Htet/Projects/TikTok/zero_shot_face_recognition/fourth_discussion/2024_general_election_baseline\final_summary_01.csv
#
# 🏁 All videos processed. No remaining data to save in a final chunk.
